# %% [markdown]
# Samantha Ramsey<br>
# ME 391 HW #3<br>
# October, 11, 2019<br>
#
# ### Given Data
#
# |  x   |  f(x) |
# |------|-------|
# |1.0   |3.0    |
# |1.2   |3.72423|
# |1.4   |4.55886|
# |1.6   |5.40191|
# |1.8   |6.21601|
# |2.0   |6.98832|
#
# This table is for the function:
# <br>$$f(x) = 9 \ln{x} + \frac{3}{x^2}$$<br><br>
#
# ### Problem 1
# For the data in the range of $1.4 \leq x \leq 2.0$, estimate $f(1.57)$ using Divided Differences.
# <br><br>
# $$f[x_0, x_1, ..., x_n] = \displaystyle\frac{f[x_1, x_2, ..., x_n] - f[x_0, x_1, ..., x_{n-1}]}{x_n - x_0}$$
# <br><br>
# $$P_n(x) = f[x_0] + f[x_0, x_1](x - x_0) + f[x_0, x_1, x_2](x - x0)(x - x_1) +...$$
# <br><br>
# $$\begin{matrix}
# x_i &  f_i     &  f[x_i, x_{i+1}] &  f[x_i, x_{i+1}, x_{i+2}]&  f[x_i, x_{i+1}, x_{i+2}, x_{i+3}]\\
# ----&----------& ----------       & ----------               & ----------                        \\
# 1.4 &  4.55886 &  4.21525         &  \text{-}0.361875        & \text{-}0.2675                    \\
# 1.6 &  5.40191 &  4.07050         &  \text{-}0.522375        &                                   \\
# 1.8 &  6.21601 &  3.86155         &                          &                                   \\
# 2.0 &  6.98832 &                  &                          &                                   \\
# \end{matrix}$$
# <br><br>
# <br><br>
# Approximation:
# <br>
# $$ f(1.57) = 4.55886 + 4.21525(1.57 - 1.4) + \text{-}0.361875(1.57 - 1.4)(1.57 - 1.6) + \text{-}0.2675(1.57 - 1.4)(1.57 - 1.6)(1.57 - 1.8) = 5.276827 $$
# <br><br>
# Actual Value:
# <br>
# $$ f(1.57) = 9 \ln{1.57}+ \frac{3}{1.57^2} = 5.276768$$
#
#
# ### Probem 2
# Using Ordinary Differences for the table above, estimate $f(1.27)$ by using:<br>
# $a$. Forward-difference polynomials for $x= [1.0, 1.4, 1.8]$. Then, do forward-difference polynomials again for $x = [1.0, 1.2, 1.4, 1.6, 1.8]$.<br>
# $b$. Backward-difference polynomials for $x= [1.0, 1.4, 1.8]$. Then, do backward-difference polynomials again for $x = [1.0, 1.2, 1.4, 1.6, 1.8]$.<br><br>
# Compute the errors of $a$ and $b$ and discuss the behavior of the errors with respect to step-size.
# <br><br>
# $$P_n(x) = f_0 + s\Delta f_0 + \displaystyle\frac{s(s-1)}{2!} \Delta^2f_0 + ... + \displaystyle\frac{s(s-1)(s-2)...(s-n)}{(n+1)!}\Delta^{n+1} f_0$$
# <br><br>
# Ordinary Difference Table 1:
# $$\begin{matrix}
# x_i &  f_i     & \Delta f_i       & \Delta^2 f_i     \\
# ----& -------- & --------         & --------         \\
# 1.0 &  3.0     &                  &                  \\
#     &          &  1.55886         &                  \\
# 1.4 &  4.55886 &                  &  0.09829         \\
#     &          &  1.65715         &                  \\
# 1.8 &  6.21601 &                  &                  \\
# \end{matrix}$$
#
# <br><br>
# Ordinary Difference Table 2:
# $$\begin{matrix}
# x_i &  f_i     & \Delta f_i       & \Delta^2 f_i  & \Delta^3 f_i & \Delta^4 f_i  \\
# ----& -------- & --------         & --------         & --------        & --------\\
# 1.0 &  3.0     &                  &                  &                 &         \\
#     &          &  0.72423         &                  &                 &         \\
# 1.2 &  3.72423 &                  & 0.11040          &                 &         \\
#     &          &  0.83463         &                  & \text{-}0.10198 &         \\
# 1.4 &  4.55886 &                  & 0.00842          &                 & 0.06461 \\
#     &          &  0.84305         &                  & \text{-}0.03737 &         \\
# 1.6 &  5.40191 &                  & \text{-}0.02895  &                 &         \\
#     &          &  0.81410         &                  &                 &         \\
# 1.8 &  6.21601 &                  &                  &                 &         \\
# \end{matrix}$$
#
# <br><br>
# $$h_1 = 0.4 \qquad\Longrightarrow\qquad s_1 = \displaystyle\frac{x - x_0}{h} = \displaystyle\frac{1.27 - 1.4}{0.4} = \text{-}0.325$$<br>
# $$h_2 = 0.2 \qquad\Longrightarrow\qquad s_1 = \displaystyle\frac{x - x_0}{h} = \displaystyle\frac{1.27 - 1.4}{0.2} = \text{-}0.650$$
#
# <br><br>
# $a$. Using $x = 1.4$:
# <br><br>
# Forward-difference polynomial for $x= [1.0, 1.4, 1.8]$
# <br><br>
# $$\begin{matrix}
# P_0(1.4) = 4.55886 & Error = 0.547704176 \\
# P_1(1.4) = 4.55886 + \text{-}0.325(1.65715) = 4.02028625 & Error = 0.0091304258 \\
# \end{matrix}$$
#
# <br><br>Forward-difference polynomial for $x= [1.0, 1.2, 1.4, 1.6, 1.8]$.<br><br>
# $$\begin{matrix}
# P_0(1.4) = 4.55886 & Error = 0.547704176 \\
# P_1(1.4) = 4.55886 + \text{-}0.650(0.84305) = 4.0108775 & Error = 0.007619176 \\
# P_2(1.4) = 4.55886 + \text{-}0.650(0.84305) + \displaystyle\frac{\text{-}0.650(\text{-}0.650 - 1)}{2!}(\text{-}0.02895) = 3.995353063 & Error = 0.015802761 \\
# \end{matrix}$$
#
# <br><br>
# $b$. Using $x = 1.4$:
# <br><br>
# Backward-difference polynomial for $x= [1.0, 1.4, 1.8]$
# <br><br> $$\begin{matrix}
# P_0(1.4) = 4.55886                                      & Error = 0.547704176 \\
# P_1(1.4) = 4.55886 + \text{-}0.325(1.55886) = 4.0522305 & Error = 0.041074676 \\
# \end{matrix}$$
#
# <br><br>Backward-difference polynomial for $x= [1.0, 1.2, 1.4, 1.6, 1.8]$.<br><br>
# $$\begin{matrix}
# P_0(1.4) = 4.55886 & Error = 0.547704176 \\
# P_1(1.4) = 4.55886 + \text{-}0.650(0.83463) = 4.0163505 & Error = 0.005194676 \\
# P_2(1.4) = 4.55886 + \text{-}0.650(0.83463) + \displaystyle\frac{\text{-}0.650(\text{-}0.650 - 1)}{2!}(0.11040) = 4.0037925 & Error = 0.007363324 \\
# \end{matrix}$$
#
# <br><br>
# $c$. Compare the Errors:<br>
# Exact Value:
# <br><br>$$ f(1.27) = 9 \ln{1.27}+ \frac{3}{1.27^2} = 4.011155824$$<br><br>
# $$Error = |Numerical Approximation - Exact Value|$$
# <br><br>
#
# As the order of the polynomial grows, the error decreases. Also, theoretically, as the step size becomes smaller, the error should decrease as well. We see this in the results of the backward-difference method, but not in the forward-difference method. It's possible the results are skewed because we did not start at the closest x-value to what we were trying to estimate. Additionally, the backwards-difference method seems to result in a smaller error.
#
#
#
# ### Problem 3
#
# |  x   |  f(x)  |
# |------|--------|
# |1.6   |0.463828|
# |1.8   |0.336809|
# |2.0   |0.244573|
# |2.2   |0.177597|
# |2.4   |0.128962|
#
# <br><br>Using the table above, determine the least squares approximation of the function:
# <br><br>$$f(x) = A e^{bx}$$
# <br><br>Linearize the function:
# <br>$$ \ln{y} = \ln{A} + bx$$
# <br>Let: $$Y = \ln{y} \qquad a = \ln{A}$$
# <br>$$Y = bx + a$$
#
# <br><br>
# $$\begin{bmatrix}
# \sum\limits_{i = 1}^{N} x_i^2   & \sum\limits_{i = 1}^{N} x_i \\
# \sum\limits_{i = 1}^{N} x_i     & \sum\limits_{i = 1}^{N} 1   \\
# \end{bmatrix}
# \begin{bmatrix}
#   \\
# b \\
#   \\
# a \\
# \end{bmatrix}
# =
# \begin{bmatrix}
# \sum\limits_{i = 1}^{N} Y_i x_i \\
# \sum\limits_{i = 1}^{N} Y_i     \\
# \end{bmatrix}$$
#
# <br><br>
# $$\begin{bmatrix}
#     20.4   & 10 \\
#     10     & 5  \\ \end{bmatrix} \begin{bmatrix}
#     b \\
#     a \\ \end{bmatrix} = \begin{bmatrix}
#     -14.72239429 \\
#     -7.041198038 \\ \end{bmatrix}$$
#
# <br><br>$$b = \text{-}1.599995535$$
# <br>$$a = 1.791751462$$
# <br>$$Y = \text{-}1.599995535x + 1.791751462$$
# <br>$$e^{Y} = e^{1.791751462} + e^{\text{-}1.599995535x}$$
# <br>$$f(x) = 5.999951957e^{\text{-}1.599995535x}$$
#
# <br><br>
# Testing the solution:
# <br><br>$$ f(x_1) = 6e^{\text{-}1.6(1.6)} =0.463828$$
#
# <br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br>
